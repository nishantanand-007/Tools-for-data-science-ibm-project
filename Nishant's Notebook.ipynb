# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nishant Anand**

# %% [markdown]
# Data Scientist

# %% [markdown]
#  *I am interested in Data Science because I would love to contribute towards security in financial sector in the future*

# %% [markdown]
# ### The below code should print 'Hello IBM WATSON STUDIO'

# %%
print('Hello IBM WATSON STUIDO')
# Out:
# Hello IBM WATSON STUIDO

# %% [markdown]
# Data Science
#
# ---
#
# Data Visualisation
#
# ***
#
# EDA
#
# ___
#
# Machine Learning

# %% [markdown]
# Data Science | EDA | Machine Learning
# --- | --- | ---
# **IMP** | **VIMP** | **DEPLOY**
# 1 | 2 | 3

# %% [markdown]
# > Top Tools of Data science.
# > MATLAB,ggplot,Tableau,JUPYTER,NLTK.
